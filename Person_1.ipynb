# %%
import numpy             as np
import matplotlib.pyplot as plt

import ipywidgets      as widgets
from   ipywidgets      import Button, HBox, VBox
from   IPython.display import display
from   IPython.display import clear_output
from IPython.display import display, HTML


filename   = 'CIFAR 10 Test Batch-Copy1'
filename2 = 'Batch Names-Copy1'


#file = np.load('databatches4survey/'+filename)

file = np.load(filename)
file2 = np.load(filename2)

# load the data onto this document

#file.files

#dict = unpickle(file)
images = file['data']
labels = file['labels']
label_names = file2['label_names']


# The original shape is 500x3072,
# 500 lists with 3072 elements in each list

images = images.reshape(len(labels), 3, 32, 32)
# reshape the type of images to be an array of 10,000x3x32x32 

# ((32 lists with 32 elements inside (pixels)) - divided into 3 lists (RGB) )
# There are 10000 of these (however many images inside the file)

def imagshow(img):
    plt.imshow(np.transpose(img, (1, 2, 0))) #flip the grid from side to normal
    plt.show()
# show the image 
    
exImages = np.random.randint(0,len(labels))


#example image 


images  = images[:200,:,:,:]              #Images 0 - 199
person_2  = images[200:400,:,:,:]           #Images 200 - 400
person_3  = images[400:600,:,:,:]           #Images 400 - 600
person_4  = images[600:800,:,:,:]           #Images 600 - 800
person_5  = images[800:1000,:,:,:]          #Images 800 - 1000
person_6  = images[1000:1200,:,:,:]         #Images 1000 - 1200
person_7  = images[1200:1400,:,:,:]         #Images 1200 - 1400
person_8  = images[1400:1600,:,:,:]         #Images 1400 - 1600
person_9  = images[1600:1800,:,:,:]         #Images 1600 - 1800
person_10 = images[1800:2000,:,:,:]         #Images 1800 - 2000
person_11 = images[2000:2200,:,:,:]         #Images 1000 - 2200
person_12 = images[2200:2400,:,:,:]         #Images 2200 - 2400
person_13 = images[2400:2600,:,:,:]         #Images 2400 - 2600
person_14 = images[2600:2800,:,:,:]         #Images 2600 - 2800
person_15 = images[2800:3000,:,:,:]         #Images 2800 - 3000
person_16 = images[3000:3200,:,:,:]         #Images 3000 - 3200
person_17 = images[3200:3400,:,:,:]         #Images 3200 - 3400
person_18 = images[3400:3600,:,:,:]         #Images 3400 - 3600
person_19 = images[3600:3800,:,:,:]         #Images 3600 - 3800
person_20 = images[3800:4000,:,:,:]         #Images 3800 - 4000
person_21 = images[4000:4200,:,:,:]         #Images 4000 - 4200
person_22 = images[4200:4400,:,:,:]         #Images 4200 - 4400
person_23 = images[4400:4600,:,:,:]         #Images 4400 - 4600
person_24 = images[4600:4800,:,:,:]         #Images 4600 - 4800
person_25 = images[4800:5000,:,:,:]         #Images 4800 - 5000
person_26 = images[5000:5200,:,:,:]         #Images 5000 - 5200
person_27 = images[5200:5400,:,:,:]         #Images 5200 - 5400
person_28 = images[5400:5600,:,:,:]         #Images 5400 - 5600
person_29 = images[5600:5800,:,:,:]         #Images 5600 - 5800
person_30 = images[5800:6000,:,:,:]         #Images 5800 - 6000
person_31 = images[6000:6200,:,:,:]         #Images 6000 - 6200
person_32 = images[6200:6400,:,:,:]         #Images 6200 - 6400
person_33 = images[6400:6600,:,:,:]         #Images 6400 - 6600
person_34 = images[6600:6800,:,:,:]         #Images 6600 - 6800
person_35 = images[6800:7000,:,:,:]         #Images 6800 - 7000
person_36 = images[7000:7200,:,:,:]         #Images 7000 - 7200
person_37 = images[7200:7400,:,:,:]         #Images 7200 - 7400
person_38 = images[7400:7600,:,:,:]         #Images 7400 - 7600
person_39 = images[7600:7800,:,:,:]         #Images 7600 - 7800
person_40 = images[7800:8000,:,:,:]         #Images 7800 - 8000
person_41 = images[8000:8200,:,:,:]         #Images 8000 - 8200
person_42 = images[8200:8400,:,:,:]         #Images 8200 - 8400
person_43 = images[8400:8600,:,:,:]         #Images 8400 - 8600
person_44 = images[8600:8800,:,:,:]         #Images 8600 - 8800
person_45 = images[8800:9000,:,:,:]         #Images 8800 - 9000
person_46 = images[9000:9200,:,:,:]         #Images 9000 - 9200
person_47 = images[9200:9400,:,:,:]         #Images 9200 - 9400
person_48 = images[9400:9600,:,:,:]         #Images 9400 - 9600
person_49 = images[9600:9800,:,:,:]         #Images 9600 - 9800
person_50 = images[9800:10000,:,:,:]        #Images 9800 - 10000


#Split the photos up to make 50 copies for people, with 200 photos in each batch

I = 0
#variable used, original value is 0
answers = []
#The results of people's answers in the survey
outfile = 'ans_'+filename
#A file with all of the answers (I create this one)
datalen = len(labels)
#The length of all data of images

def on_buttonNext_clicked(b):
    global I 
    #Only changes I for individual actions
    I = I+1
    with out: 
        #Do the things within "out" - which is the widget output
        row = []
        #The newlist that the answers will be appended to
        for l in range(0,len(widget_labels)): #Creating widget answers by changing the individual widget values
            row.extend([items[l].value]) #appending the widget answers 
            items[l].value = 0 #Resets the values 
        answers.append(row) #Puts in the new row answers into the overall answers
        clear_output() #Resets the widget numbers
        imagshow(images[I]) #Displays a new image
        if I % 1 == 0: #Saves answers
            saveAnswers(b)
        

        
def saveAnswers(b):
    image = images.reshape(200, 3*32*32)
    #Convert the images back into normal data
    np.savez(outfile, answers=answers, images=image, labels=labels, label_names=label_names)
    #Save the new outfile(with new answers), new answers, new images, new labels, and new label names

# %% [markdown]
# # Image Survey
#
# ### Instructions for the survey:
#
# There will be displayed an image in front of you. You must go through each category below the image and choose the probability that the image may be the category given.
#
# Give a rating on how sure you are about the image belonging to each category:
#
# 4 = You can say with 100% certainty that the photo definitely belongs to this category <br>
# 3 = It's probably this category, but there are details that can be interpreted as something else <br>
# 2 = The image might be in this category, but definitely can be in another category too <br>
# 1 = There's a small chance that the image is part of this category <br>
# 0 = There is no way this image falls under this category and there are no details of this in the image <br>
#
# Try to choose at least 3 categories to be non-zero.
#
# You will recieve around 200 photos to look at and rate how much they look like each object. This should take around 2 hours. Let Ophir know if you have any questions.

# %%
widget_labels = ['airplane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
confidence    = [4, 3, 2, 1, 0]


items  = [widgets.RadioButtons(options=confidence, 
                layout=widgets.Layout(width='50px', height='150px'), value = 0) for l in widget_labels] 
#Actually displays the widgets and numbers
buttonNext = Button(description='Next')
widgetsBox = HBox([VBox([widgets.Label(widget_labels[l]), items[l]]) for l in range(0,len(widget_labels))])
out        = widgets.Output()




                        
buttonNext.on_click(on_buttonNext_clicked)


display(VBox([widgetsBox, buttonNext]))

with out:
    imagshow(images[I])

out
# Out:
# VkJveChjaGlsZHJlbj0oSEJveChjaGlsZHJlbj0oVkJveChjaGlsZHJlbj0oTGFiZWwodmFsdWU9dSdhaXJwbGFuZScpLCBSYWRpb0J1dHRvbnMoaW5kZXg9NCwgbGF5b3V0PUxheW91dChoZWnigKY=
# Output()
